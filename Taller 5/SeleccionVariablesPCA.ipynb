# %% [markdown]
# <a href="https://colab.research.google.com/github/Alzategelizabeth/Cartografia-/blob/main/Taller%205/SeleccionVariablesPCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasterio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ##**INVENTARIO**

# %%
#Libreria
import rasterio as rio
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
raster = rio.open('https://github.com/Alzategelizabeth/Cartografia-/blob/main/Taller%205/morfometria/InventarioMenM.tif?raw=true')
inventario=raster.read(1)
inventario=np.where(inventario>1,np.nan,inventario)#np.where--cambia los valores menores a 0
inventario_vector=inventario.ravel()
inventario_vector_MenM=inventario_vector[~np.isnan(inventario_vector)] # para eliminar  del vector los datos No data y dejar solo los que tienen datos en la cuenca
plt.imshow(inventario)
plt.colorbar()
inventario_vector_MenM.shape
# Out:
# (821560,)

# %%
np.unique(inventario)#para conocer los numeros almacenados en el raster
# Out:
# array([ 0.,  1., nan])

# %% [markdown]
# ##**SELECCIÓN DE VARIABLES**

# %% [markdown]
# **PENDIENTE**

# %%
import rasterio as rio
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns #libreria para graficar
from pandas import DataFrame
import statsmodels.graphics.api as smg #libreria de estadistica

# %%
raster = rio.open('https://github.com/Alzategelizabeth/Cartografia-/blob/main/Taller%205/morfometria/pendiente2.tif?raw=true')
pendiente=raster.read(1)
pendiente=np.where(pendiente<0,np.nan,pendiente)
pendiente_vector=pendiente.ravel()
pendiente_vector_MenM=pendiente_vector[~np.isnan(pendiente_vector)]
plt.imshow(pendiente)
plt.colorbar()
pendiente_vector_MenM.shape
# Out:
# (821560,)

# %%
np.shape(pendiente)#conocer el tamaño de la matriz
# Out:
# (1176, 1215)

# %%
~np.isnan(pendiente_vector)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
np.unique(pendiente)
# Out:
# array([0.00000000e+00, 1.25811982e-03, 1.25812134e-03, ...,
#        6.94258118e+01, 6.95717773e+01,            nan])

# %% [markdown]
# **ASPECTO**

# %%
raster = rio.open('https://github.com/Alzategelizabeth/Cartografia-/blob/main/Taller%205/morfometria/aspecto.tif?raw=true')
aspecto=raster.read(1)
aspecto=np.where(aspecto<-2,np.nan,aspecto)
aspecto=np.where(aspecto<0,0,aspecto)
aspecto_vector=aspecto.ravel()
aspecto_vector_MenM=aspecto_vector[~np.isnan(aspecto_vector)]
plt.imshow(aspecto)
plt.colorbar()
aspecto_vector_MenM.shape
# Out:
# (821560,)

# %%
np.unique(aspecto)
# Out:
# array([0.00000000e+00, 9.06258821e-04, 1.48492889e-03, ...,
#        3.59998108e+02, 3.59999054e+02,            nan])

# %% [markdown]
# **CURVATURA**

# %%
raster = rio.open('https://github.com/Alzategelizabeth/Cartografia-/blob/main/Taller%205/morfometria/curvatura.tif?raw=true')
curvatura=raster.read(1)
curvatura=np.where(curvatura>3,np.nan,curvatura)
curvatura_vector=curvatura.ravel()
curvatura_vector_MenM=curvatura_vector[~np.isnan(curvatura_vector)]
plt.imshow(curvatura)
plt.colorbar()
np.unique(curvatura)
curvatura_vector_MenM.shape
# Out:
# (821560,)

# %%
curvatura_vector_MenM.shape
# Out:
# (821560,)

# %%
np.unique(curvatura_vector_MenM)
# Out:
# array([1., 2., 3.])

# %% [markdown]
# **GEOLOGÍA**

# %%
raster = rio.open('https://github.com/Alzategelizabeth/Cartografia-/blob/main/Taller%205/morfometria/geologia.tif?raw=true')
geologia=raster.read(1)
geologia=np.where(geologia>3,np.nan,geologia)
geologia_vector=geologia.ravel()
geologia_vector_MenM=geologia_vector[~np.isnan(geologia_vector)]
plt.imshow(geologia)
plt.colorbar()
geologia_vector_MenM.shape
# Out:
# (821560,)

# %%
np.unique(geologia)
# Out:
# array([ 1.,  2.,  3., nan])

# %% [markdown]
# **GEOMORFOLOGÍA**

# %%
raster = rio.open('https://github.com/Alzategelizabeth/Cartografia-/blob/main/Taller%205/morfometria/subunidades.tif?raw=true')
geomorfologia=raster.read(1)
geomorfologia=np.where(geomorfologia<1,np.nan,geomorfologia)
geomorfologia_vector=geomorfologia.ravel()
geomorfologia_vector_MenM=geomorfologia_vector[~np.isnan(geomorfologia_vector)]
plt.imshow(geomorfologia)
plt.colorbar()
geomorfologia_vector_MenM.shape
# Out:
# (821560,)

# %%
np.unique(geomorfologia)
# Out:
# array([1. , 1.5, 2. , 2.2, 2.8, 3. , 3.5, 4.2, nan])

# %% [markdown]
# **FLUJO ACUMULADO**

# %%
raster = rio.open('https://github.com/Alzategelizabeth/Cartografia-/blob/main/Taller%205/morfometria/Flujoacumulado.tif?raw=true')
flujo=raster.read(1)
flujo=np.where(flujo<0,np.nan,flujo)
flujo_vector=flujo.ravel()
flujo_vector_MenM=flujo_vector[~np.isnan(flujo_vector)]
plt.imshow(flujo)
plt.colorbar()
flujo_vector_MenM.shape
# Out:
# (821560,)

# %%
np.unique(flujo)
# Out:
# array([0.00000e+00, 1.00000e+00, 2.00000e+00, ..., 2.45783e+05,
#        2.45876e+05,         nan])

# %% [markdown]
# **ELEVACIÓN**

# %%
raster = rio.open('https://github.com/Alzategelizabeth/Cartografia-/blob/main/Taller%205/morfometria/Elevacion.tif?raw=true')
elevacion=raster.read(1)
elevacion=np.where(elevacion<1,np.nan,elevacion)
elevacion_vector=elevacion.ravel()
elevacion_vector_MenM=elevacion_vector[~np.isnan(elevacion_vector)]
plt.imshow(elevacion)
plt.colorbar()
elevacion_vector_MenM.shape
# Out:
# (821560,)

# %%
np.unique(elevacion)
# Out:
# array([2109.13354492, 2109.44750977, 2109.46679688, ..., 2930.06567383,
#        2930.24414062,           nan])

# %% [markdown]
# ##**DATA FRAME**

# %%
d={'inventario':inventario_vector_MenM,'geomorfologia':geomorfologia_vector_MenM,'geologia':geologia_vector_MenM,'aspecto':aspecto_vector_MenM,'pendiente':pendiente_vector_MenM,'flujo':flujo_vector_MenM,'elevacion':elevacion_vector_MenM,'curvatura':curvatura_vector_MenM}
df = pd.DataFrame(d)
print(list(df.columns))
# Out:
# ['inventario', 'geomorfologia', 'geologia', 'aspecto', 'pendiente', 'flujo', 'elevacion', 'curvatura']

# %%
df.head()
# Out:
#    inventario  geomorfologia  geologia     aspecto  pendiente  flujo  \
# 0         0.0            3.0       3.0  138.732468  35.672390    7.0
# 1         0.0            3.0       3.0  137.794312  35.078232    8.0
# 2         0.0            3.0       3.0  140.078018  32.974354    9.0
# 3         0.0            3.0       3.0  142.213806  34.152977   10.0
# 4         0.0            3.0       3.0  111.181129  15.028431    0.0
#
#      elevacion  curvatura
# 0  2600.191895        1.0
# 1  2599.265381        1.0
# 2  2598.339111        1.0
# 3  2597.632080        1.0
# 4  2559.579590        3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 821560 entries, 0 to 821559
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   inventario     821560 non-null  float64
#  1   geomorfologia  821560 non-null  float64
#  2   geologia       821560 non-null  float64
#  3   aspecto        821560 non-null  float64
#  4   pendiente      821560 non-null  float64
#  5   flujo          821560 non-null  float64
#  6   elevacion      821560 non-null  float64
#  7   curvatura      821560 non-null  float64
# dtypes: float64(8)
# memory usage: 50.1 MB

# %%
df1=df[(df["inventario"]==1) | (df["inventario"]==0).sample(frac=.1)]#se genera un df que solo trabaja con  el 10%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82205 entries, 30 to 821555
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   inventario     82205 non-null  float64
#  1   geomorfologia  82205 non-null  float64
#  2   geologia       82205 non-null  float64
#  3   aspecto        82205 non-null  float64
#  4   pendiente      82205 non-null  float64
#  5   flujo          82205 non-null  float64
#  6   elevacion      82205 non-null  float64
#  7   curvatura      82205 non-null  float64
# dtypes: float64(8)
# memory usage: 5.6 MB

# %%
resumen=df1.describe().T
print(resumen)
# Out:
#                  count         mean          std         min          25%  \
# inventario     82205.0     0.000633     0.025143     0.00000     0.000000
# geomorfologia  82205.0     2.980822     0.420656     1.00000     3.000000
# geologia       82205.0     2.899288     0.391525     1.00000     3.000000
# aspecto        82205.0   238.884212    93.642455     0.00000   206.048798
# pendiente      82205.0    26.709440    11.925258     0.00000    17.884050
# flujo          82205.0   242.213089  3258.597516     0.00000     5.000000
# elevacion      82205.0  2542.601745   175.566832  2109.44751  2412.767090
# curvatura      82205.0     1.989587     0.739985     1.00000     1.000000
#
#                        50%          75%            max
# inventario        0.000000     0.000000       1.000000
# geomorfologia     3.000000     3.000000       4.200000
# geologia          3.000000     3.000000       3.000000
# aspecto         263.702118   304.858124     359.997894
# ...

# %%
matriz=df1.drop(['inventario'],axis=1) # función para eliminar una columna (axis=1)
matriz.head()
# Out:
#     geomorfologia  geologia     aspecto  pendiente  flujo    elevacion  \
# 30            3.0       3.0  147.017548  27.941305   11.0  2595.234131
# 46            3.0       3.0  119.404053  22.001947    2.0  2557.449951
# 59            3.0       3.0  149.107224  31.583569   10.0  2590.680176
# 65            3.0       3.0  130.244522  12.746238    7.0  2562.190674
# 70            3.0       3.0  142.216309  13.088979    6.0  2560.622070
#
#     curvatura
# 30        2.0
# 46        1.0
# 59        1.0
# 65        1.0
# 70        2.0

# %%
matriz_cont=matriz.drop(['geologia','geomorfologia','curvatura'],axis=1)
matriz_cont.head()
# Out:
#        aspecto  pendiente  flujo    elevacion
# 30  147.017548  27.941305   11.0  2595.234131
# 46  119.404053  22.001947    2.0  2557.449951
# 59  149.107224  31.583569   10.0  2590.680176
# 65  130.244522  12.746238    7.0  2562.190674
# 70  142.216309  13.088979    6.0  2560.622070

# %% [markdown]
# ##**Analisis de todas las variables**

# %%
 pd.plotting.scatter_matrix(matriz_cont, alpha = 0.3, figsize = (14,10), diagonal='kde')#análisis de de variables continuas
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f37013706d0>,
# ...
#       dtype=object)

# %%
sns.pairplot(df1, hue='inventario')

# %%
matriz.plot(kind='density', subplots=True, layout=(3, 3), sharex=False, figsize=(10, 6))# para conocer la densidad de los datos
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f36fa8c6610>,
# ...
#       dtype=object)

# %%
MatCorre=DataFrame(df.corr())
smg.plot_corr(MatCorre, xnames=list(MatCorre.columns))

# %% [markdown]
# ##**Análisis univariado**

# %% [markdown]
# **Pendiente**

# %%
df.pendiente.hist()
plt.title('Histograma de Pendiente')
plt.xlabel('Pendiente')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
plt.boxplot(df['pendiente'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6f778d65d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6f778d4090>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6f778b3fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6f778d4b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6f778be0d0>],
#  'means': []}

# %%
sns.distplot(df['pendiente'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Aspecto**

# %%
df.aspecto.hist()
plt.title('Histograma de Aspecto')
plt.xlabel('Aspecto')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
plt.boxplot(df['aspecto'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6f73335a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6f7333b550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6f73335510>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6f73342050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6f73342590>],
#  'means': []}

# %%
sns.distplot(df['aspecto'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Acumulación de flujo**

# %%
df.flujo.hist()
plt.title('Histograma de Flujo')
plt.xlabel('Flujo')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
sns.distplot(df['flujo'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Elevación**

# %%
df.elevacion.hist()
plt.title('Histograma de Elevacion')
plt.xlabel('Flujo')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
plt.boxplot(df['elevacion'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6f75dba190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6f75def8d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6f75e0d7d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6f75e138d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6f75e13050>],
#  'means': []}

# %%
sns.distplot(df['elevacion'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##**Análisis Multivariado**

# %%
sns.jointplot(x='pendiente', y='elevacion', data=df1, kind='scatter')

# %% [markdown]
# ##**Correlación con la variable dependiente**

# %%
media=df.groupby('inventario').mean()#con groupby se busca saber la media de las variables independientes con respecto a la variable dependiente
print(media)
# Out:
#             geomorfologia  geologia     aspecto  pendiente       flujo  \
# inventario
# 0.0              2.981287  2.901215  238.638834  26.675219  249.036832
# 1.0              3.230769  2.942308  201.736658  36.314431   10.480769
#
#               elevacion  curvatura
# inventario
# 0.0         2542.806233   1.991965
# 1.0         2394.639911   2.211538

# %%
#Para contar el numero de celdas con y sin MenM
df['inventario'].value_counts()
# Out:
# 0.0    821508
# 1.0        52
# Name: inventario, dtype: int64

# %%
landslides=df.inventario.astype(bool)#Se busca generar un nuevo DF para MenM y no MenM
si_lands=df[landslides]
no_lands=df[~landslides]

# %%
si_lands.count()
# Out:
# inventario       52
# geomorfologia    52
# geologia         52
# aspecto          52
# pendiente        52
# flujo            52
# elevacion        52
# curvatura        52
# dtype: int64

# %%
no_lands.count()
# Out:
# inventario       821508
# geomorfologia    821508
# geologia         821508
# aspecto          821508
# pendiente        821508
# flujo            821508
# elevacion        821508
# curvatura        821508
# dtype: int64

# %%
df.boxplot('pendiente', by='inventario', notch=True, widths=0.8, showmeans=True, meanline=True)
plt.plot([], [], '--', linewidth=1, color='red', label='mean')
plt.plot([], [], '-', linewidth=1, color='blue', label='median')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
from scipy import stats#se realiza una prueba de hipotesis paraonfirmar si las dos poblaciones pendientes con MenM y pendientes sin MenM son poblaciones diferentes
stats.ttest_ind(no_lands["pendiente"], si_lands["pendiente"])
# Out:
# Ttest_indResult(statistic=-5.839592292574306, pvalue=5.234831508028921e-09)

# %%
fig, ax = plt.subplots()
si_lands['pendiente'].plot.kde(ax=ax, label='Sin MenM')
no_lands['pendiente'].plot.kde(ax=ax, label='Con MenM')
ax.set_xlim(0,90)
ax.set_xlabel('Pendiente (°)', color='k', size=12)
ax.set_ylabel('Densidad', color='k', size=12)
ax.legend(loc=1, fontsize=10)
ax.tick_params('y', colors='k', labelsize= 10)

# %%
sns.distplot(si_lands['pendiente'])
sns.distplot(no_lands['pendiente']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##**Análisis de Componentes principales (PCA)**

# %%
#se importan todas las librerias a utilizar
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

#Se importan los archivos
data= df
puntos=data['inventario']
data.drop('inventario', axis=1, inplace=True)

# Se debe escalar los datos antes de aplicar PCA
data = pd.DataFrame(scale(data), columns=['geologia', 'geomorfologia', 'curvatura', 'flujo', 'elevacion', 'aspecto','pendiente'])

## Se implementa el análisi PCA con la libreria sklearn de python
n = len(data.columns)
pca = PCA(n_components=n)
pca = pca.fit(data)
pca_samples = pca.transform(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-c980a71f0e20> in <module>
#      49
#      50 plt.scatter(xs, ys, s=70,marker='x',c='blue', label='MenM')
# ---> 51 plt.sc
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sc'

# %%
#Se puede graficar cuanto aporta a la varianza cada componente generado
plt.plot(pca.explained_variance_ratio_)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
plt.show()

#graficamos el acumulado de varianza explicada en las nuevas dimensiones
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

#Para identificar cada variable como se relaciona con las componentes utilizamos las figuras byplot de python
# 0,1 denota el componente princiapl 1 y 2 (PC1 and PC2); para otros componentes se modifica el número
xvector = pca.components_[0] 
yvector = pca.components_[1]

xs = pca.transform(data)[:,0] # Componente principal 1
ys = pca.transform(data)[:,1] # Componente principal 2

mask1=np.ma.masked_where(puntos < 1,xs )
mask2=np.ma.masked_where(puntos < 1,ys ) 

## Para visualizar las proyecciones de cada variable en los componentes se utiliza la siguiente función
for i in range(len(xvector)):
# arrows project features (ie columns from csv) as vectors onto PC axes
    plt.arrow(0, 0, xvector[i]*0.5*max(xs), yvector[i]*0.5*max(ys),
              color='r', width=0.0005, head_width=0.0025)
    plt.text(xvector[i]*0.5*max(xs)*1.2, yvector[i]*0.5*max(ys)*1.2,
             list(data.columns.values)[i], color='r') 

plt.scatter(xs, ys, s=70,marker='x',c='blue', label='MenM')
plt.scatter(mask1,mask2,facecolors='black', edgecolors='black', s=70, alpha=0.5, label='No MenM')
plt.tick_params('y', colors='k', labelsize=12, length=2)
plt.tick_params('x', colors='k', labelsize= 12, length=2)
plt.xlabel("Componente Principal 1", fontsize=16)
plt.ylabel("Componente Principal 2", fontsize=16)
plt.legend(fontsize=14)
plt.ylim([-15, 50])
plt.show()

# %%
def pca_results(data, pca):
    
    dimensions = ['Dim. {}'.format(i) for i in range(1,len(pca.components_)+1)]
    
    components = pd.DataFrame(np.round(pca.components_, 4), columns = data.keys()) 
    components.index = dimensions

    ratios = pca.explained_variance_ratio_.reshape(len(pca.components_), 1) 
    variance_ratios = pd.DataFrame(np.round(ratios, 4), columns = ['Explained Variance']) 
    variance_ratios.index = dimensions

    fig, ax = plt.subplots(figsize = (14,8))

    components.plot(ax = ax, kind = 'bar')
    ax.set_ylabel("Feature Weights") 
    ax.set_xticklabels(dimensions, rotation=0)

    for i, ev in enumerate(pca.explained_variance_ratio_): 
        ax.text(i-0.40, ax.get_ylim()[1] + 0.05, "Expl. Var.\n %.4f"%(ev))

    return pd.concat([variance_ratios, components], axis = 1)

pca_results = pca_results(data, pca)
